# %% [markdown]
# #Week 13

# %% [markdown]
# Classification Task with random Forest
#
# Refrence:https://en.wikipedia.org/wiki/Random_forest

# %% [markdown]
# General ML Model Training

# %% [markdown]
# ![Machine-learning-general-process.jpeg](attachment:Machine-learning-general-process.jpeg)

# %% [markdown]
# Ensemble Learning: heterogeneous & homogeneous
#
# Refrence:https://en.wikipedia.org/wiki/Ensemble_learning

# %% [markdown]
# ![homogeneous-data-nodes.jpeg](attachment:homogeneous-data-nodes.jpeg)

# %% [markdown]
# Bagging:Bootstrap Aggregating
#
# Refrence:https://en.wikipedia.org/wiki/Bootstrap_aggregating#:~:text=Bootstrap%20aggregating%2C%20also%20called%20bagging,and%20helps%20to%20avoid%20overfitting.

# %% [markdown]
# ![0_fXQq704fHO18BImx.png](attachment:0_fXQq704fHO18BImx.png)

# %% [markdown]
# Random Forest
#
# Refrence:https://en.wikipedia.org/wiki/Random_forest

# %% [markdown]
# ![339333_1_En_27_Fig3_HTML.jpg](attachment:339333_1_En_27_Fig3_HTML.jpg)

# %% [markdown]
# Example Dataset With Iris

# %%
from sklearn.datasets import load_iris

X,y = load_iris(return_X_y=True)

print(f'Dimensi Feature: {X.shape}')
print(f'class: {set(y)}')
# Out:
# Dimensi Feature: (150, 4)
# class: {0, 1, 2}

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,
                                                 y,
                                                 test_size=0.3,
                                                 random_state=0)

# %% [markdown]
# Classification With #RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

model= RandomForestClassifier(n_estimators=100,
                              random_state=0)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# Evaluation Model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
