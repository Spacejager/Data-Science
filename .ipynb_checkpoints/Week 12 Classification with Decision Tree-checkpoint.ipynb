# %% [markdown]
# #Week 12

# %% [markdown]
# Classification Task with Decision Tree
#
# Refrence:https://en.wikipedia.org/wiki/Decision_tree_learning

# %% [markdown]
# Basic Concept

# %% [markdown]
# Terminology:Root node,Internal node,leaf node

# %% [markdown]
# ![0_PB7MYQfzyaLaTp1n.png](attachment:0_PB7MYQfzyaLaTp1n.png)

# %% [markdown]
# Gini Impurity

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# Left segment

# %% [markdown]
# ![02b811_5df05513ffd4487d843bb401dfa5e0cb~mv2.jpeg](attachment:02b811_5df05513ffd4487d843bb401dfa5e0cb~mv2.jpeg)

# %% [markdown]
# Information Gain

# %% [markdown]
# ![Entropy_2.png](attachment:Entropy_2.png)

# %% [markdown]
# Building Decision Tree

# %% [markdown]
# ![example-1.png](attachment:example-1.png)

# %% [markdown]
# Using iris Dataset

# %%
from sklearn.datasets import load_iris

X,y = load_iris(return_X_y=True)

print(f'Dimensi Feature: {X.shape}')
print(f'class: {set(y)}')
# Out:
# Dimensi Feature: (150, 4)
# class: {0, 1, 2}

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,
                                                 y,
                                                 test_size=0.3,
                                                 random_state=0)

# %% [markdown]
# Classification with #DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

model= DecisionTreeClassifier(max_depth=4)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# Visualization Model

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.rcParams['figure.dpi'] = 85
plt.subplots(figsize=(10, 10))
tree.plot_tree(model,fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Evaluation Model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
